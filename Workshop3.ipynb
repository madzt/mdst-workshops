# %%
import pandas as pd
 C:\Users\madelinetrumbauer\Downloads\HealthAdmissionsData.csv
        a. AdmissionLengthDays, Death_1, EnglishLanguage_1, Religion_Type, Married_1, Race, Dx
        b. floats: 1 Admission Length Days
            integers: 3 EnglishLanguage_1, Married_1, Death_1, 
        c. Admission_Type, Religion_Type, Race, Dx
        d. "private", "medicare", "government"
        e. a = [AdmissionLengthDays]
            print(statistics.mean(a))
        f. admission tye:emergency
            insurance type:medicare
                religion type: catholic
                    race: white
                        diagnosis: altered mental state
        g. 
        h. plot(avglenght, Death_1)
        i. death and insuranc
